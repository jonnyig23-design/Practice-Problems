# %%
#dictionary
my_dict={
    "name":"ABC",
    "panel":"B",
    "roll no":34,
    "marks":[65,87,97,94]
}
sorted_dict=sorted(my_dict)
print("sorted keys:",sorted_dict)
# Out:
# sorted keys: ['marks', 'name', 'panel', 'roll no']

# %%
#dictionary with highest marks
students = {
    "Aarav": 85,
    "Diya": 92,
    "Kabir": 78,
    "Ananya": 90,
    "Rohan": 88
}

highest_student=max(students,key=students.get)
print("Student with highest marks:",highest_student)
print("Highest Marks:",students[highest_student])
# Out:
# Student with highest marks: Diya
# Highest Marks: 92

# %%
#To count the frequency of each element in a list
numbers = [10,20,30,40,50,10,20,30]
frequency={}
for num in numbers:
    if num in frequency:
        frequency[num]=frequency[num]+1
    else:
        frequency[num]=1
print("Frequency of elements:",frequency)
# Out:
# Frequency of elements: {10: 2, 20: 2, 30: 2, 40: 1, 50: 1}

# %%
my_dict={
    "Aarav": 85,
    "Diya": 92,
    "Kabir": 78,
    "Ananya": 90,
    "Rohan": 88
}
sorted_dict=dict(sorted(my_dict.items(),key=lambda item:item[1]))
print("Dictionary sorted by values:",sorted_dict)
# Out:
# Dictionary sorted by values: {'Kabir': 78, 'Aarav': 85, 'Rohan': 88, 'Ananya': 90, 'Diya': 92}

# %%
score = 85
attendence = 92
if score >=70:
    print ("Student passed the exam.")
    if attendence>=90:
        print("Student also has excellent attendence")
    else:
        print("Student's attenedence could be improved ")
else:
    print("Student did not pass the exam")
# Out:
# Student passed the exam.
# Student also has excellent attendence

# %%
fruits=["apple","banana","cherry"]
for fruits in fruits:
    print(fruits)
# Out:
# apple
# banana
# cherry

# %%
count=0
while count<5:
    print(count)
    count +=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
adj=["red","big","tasty"]
fruits=["apple","banana","cherry"]
for x in adj:
    for y in fruits:
        print(x,y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %%
#Sample code for break statement
for i in range(10):
    if i==5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#Sample code for continue statement
for i in range(5):
    if i==2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4
