# %%
#list of num1
num1=[10,20,30,40,50]
print("list is : ",num1)
print("index(0):first number is : ",num1[0])
print("index(1),second number is : ",num1[1])
print("index(2),third num is : ",num1[2])
print("index(3),forth number is : ",num1[3])
print("index(4),fifth number is : ",num1[4])
# Out:
# list is :  [10, 20, 30, 40, 50]
# index(0):first number is :  10
# index(1),second number is :  20
# index(2),third num is :  30
# index(3),forth number is :  40
# index(4),fifth number is :  50

# %%
#adding a new num in list 
num1.append(60)
print("index(5),sixth number is : ",num1[5])
print("new list is : ",num1)
# Out:
# index(5),sixth number is :  60
# new list is :  [10, 20, 30, 40, 50, 60]

# %%
#to reverse a list
num1.reverse()
print("reverse list is : ",num1)
# Out:
# reverse list is :  [60, 50, 40, 30, 20, 10]

# %%
#counting occurence of an element
num2=[10,10,20,20,20,30,30]
element=int(input("enter number : "))
count=num2.count(element)
print("number of occurance is : ",count)
# Out:
# enter number :  10
# number of occurance is :  2

# %%
#adding one list in front of another list
list1=[10,20,30]
list2=[40,50,60]
list1=list2+list1
print("new list is : ",list1)
print("list2 is : ",list2)
# Out:
# new list is :  [40, 50, 60, 10, 20, 30]
# list2 is :  [40, 50, 60]

# %%
#inserting a value into a list
num=[10,20,30,40,50]
print(num)
num.insert(2,25)  #(index , value)
print("new list is :",num)
# Out:
# [10, 20, 30, 40, 50]
# new list is : [10, 20, 25, 30, 40, 50]

# %%
#remove an element using its index
num=[10,20,30,40,50]
print(num)
index=int(input("enter index to remove : "))
num.pop(index)
print("new list is : ",num)
# Out:
# [10, 20, 30, 40, 50]
# enter index to remove :  2
# new list is :  [10, 20, 40, 50]

# %%
# ii)count even odd values if list:
even=0
odd=0
for value in numbers:
    if value%2==0:
       even=even+1
    else:
       odd=odd+1
print("even: ",even)
print("odd: ",odd)
# Out:
# even:  5
# odd:  5

# %%
#Q.)accept 10 values from user:
numbers=[]
for i in range(10):
    num=int(input("enter number: "))
    numbers.append(num)
    print("list is : ",numbers)
# i)count similar elements and print list
if numbers.count(numbers[i])>1:   
    print("duplicat numbers are : ",numbers[i])
for j in range(10):
    if numbers[j]==numbers[i]:
        print("index are: ",j)
# Out:
# enter number:  3
# list is :  [3]
# enter number:  4
# list is :  [3, 4]
# enter number:  5
# list is :  [3, 4, 5]
# enter number:  6
# list is :  [3, 4, 5, 6]
# enter number:  7
# list is :  [3, 4, 5, 6, 7]
# enter number:  8
# list is :  [3, 4, 5, 6, 7, 8]
# enter number:  9
# list is :  [3, 4, 5, 6, 7, 8, 9]
# enter number:  0
# list is :  [3, 4, 5, 6, 7, 8, 9, 0]
# enter number:  9
# list is :  [3, 4, 5, 6, 7, 8, 9, 0, 9]
# enter number:  4
# list is :  [3, 4, 5, 6, 7, 8, 9, 0, 9, 4]
# duplicat numbers are :  4
# index are:  1
# index are:  9

# %%
# Q)accept 10 values from user:
numbers=[]
for i in range(10):
    num=int(input("enter number : "))
    numbers.append(num)
print("List is : ",numbers)
# Out:
# enter number :  5
# enter number :  6
# enter number :  7
# enter number :  8
# enter number :  9
# enter number :  9
# enter number :  6
# enter number :  4
# enter number :  3
# enter number :  2
# List is :  [5, 6, 7, 8, 9, 9, 6, 4, 3, 2]

# %%
#sort list in ascending ordr and display it:
ascending=sorted(numbers)
print("ascending ordr is :",ascending)
# Out:
# ascending ordr is : [2, 3, 4, 5, 6, 6, 7, 8, 9, 9]

# %%
#descending ordr:
numbers.sort(reverse=True)
print("descending ordr is : ",numbers)
# Out:
# descending ordr is :  [9, 9, 8, 7, 6, 6, 5, 4, 3, 2]

# %%
#display length of list
print("length of list is: ",len(numbers))
# Out:
# length of list is:  10

# %%
#Q) accept two list and merge into singal list:
list1=[]
for i in range(4):
    num=int(input("enter number: "))
    list1.append(num)
print("List1 is : ",list1)
# Out:
# enter number:  2
# enter number:  3
# enter number:  4
# enter number:  5
# List1 is :  [2, 3, 4, 5]

# %%
list2=[]
for i in range(3):
    num=int(input("enter number: "))
    list2.append(num)
print("List2 is : ",list2)
# Out:
# enter number:  3
# enter number:  5
# enter number:  2
# List2 is :  [3, 5, 2]

# %%
merged_list=list1+list2
print("merged list is: ",merged_list)
# Out:
# merged list is:  [2, 3, 4, 5, 3, 5, 2]

# %%
#Q)12 Acronym
phrase=input("enter phrase: ")
words=phrase.split()
acronym=""
for word in words:
    acronym=acronym+word[0]
    print("acronym: ",acronym.upper())
# Out:
# enter phrase:  afh
# acronym:  A

# %%
#Q)display abbreviation of mnth
months=["jan","feb","mar","apr","may","june","july","aug","sep","oct","nov","dec"]
mnth_num=int(input("enter number: "))
if mnth_num>=1 and mnth_num<=12:
    print("month abbreviation is: ",months[mnth_num-1])
else:
    print("hulalalal")
# Out:
# enter number:  2
# month abbreviation is:  feb

# %%
#Q)programme to insert delete and display list
numbers=[10,20,30,40]
print("List is: ",numbers)
numbers.insert(4,50)
print("new list: ",numbers)
numbers.pop(4)
print("list aftr deleting element: ",numbers)
# Out:
# List is:  [10, 20, 30, 40]
# new list:  [10, 20, 30, 40, 50]
# list aftr deleting element:  [10, 20, 30, 40]

# %%
#Q)merge two list into dict
keys=[1,2,3,4]
values=["raman","rahul","rohit","raushan"]
student_dict=dict(zip(keys,values))
print("student dict is : ",student_dict)
# Out:
# student dict is :  {1: 'raman', 2: 'rahul', 3: 'rohit', 4: 'raushan'}

# %%
#Q)to remove duplicate element from list
numbers=[1,1,2,2,2,3,4,5]
u=list(set(numbers))
print(u)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Q)to find commnon element in two list
list1=[10,20,30,40]
list2=[30,40,50,60]
common=[]
for value in list1:
    if value in list2:
        common.append(value)
print("list1 is : ",list1)
print("list2 is : ",list2)
print("commnon element is : ",common)
# Out:
# list1 is :  [10, 20, 30, 40]
# list2 is :  [30, 40, 50, 60]
# commnon element is :  [30, 40]
